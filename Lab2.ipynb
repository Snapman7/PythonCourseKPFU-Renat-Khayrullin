# %% [markdown]
# ![Снимок экрана 2025-09-11 в 20.10.54.png](data:image/png;base64,...)

# %% [markdown]
# Task 1

# %%
x = float(input())
f = 0
if (x > 3):
  f = -3 * x + 9
else:
  f = (x ** 3) / ((x ** 2) + 8)
print(f)
# Out:
# 4
# -3.0

# %% [markdown]
# Task 2

# %%
a, b, c = list(map(int, input().split()))
answer = "YES" if ((a * b) < 0 or (b * c) < 0 or (a * c) < 0) else "NO"
print(answer)
# Out:
# -1 0 1
# YES

# %% [markdown]
# Task 3

# %%
x1, y1, x2, x3, y3, x4 = list(map(int, input().split()))
if (x3 < x2):
  print("YES")
  answer = (x2 - x3) * min(y1, y3);
  print(answer)
else:
  print("NO")
# Out:
# 0 3 4 1 2 9
# YES
# 6

# %% [markdown]
# Task 4

# %%
x1, y1, a1, b1, x2, y2, a2, b2 = list(map(int, input().split()))

xLeftAns = min(x1, x2)
xRightAns = max(x1 + max(a1, b1), x2 + max(a2, b2))
yBotAns = min(y1, y2)
yTopAns = max(y1 + max(a1, b1), y2 + max(a2, b2))
print(xLeftAns, yBotAns, xRightAns, yTopAns)
# Out:
# 0 0 10 5 9 7 2 1
# 0 0 11 10

# %% [markdown]
# Task 5

# %%
def can_by_hor(b, d):
  return (b - d == 1) or (b == 7 and d == 5)

def can_by_ver_solo(a, c):
  return a == c

def can_by_ver(a, c):
  return abs(a - c) == 1

a, b, c, d = list(map(int, input().split()))
if can_by_hor(b, d):
  if can_by_ver_solo(a, c):
    print("Обычный ход: ДА", "Когда бьет фигуру: НЕТ", sep='\n')
  elif can_by_ver(a, c):
    print("Обычный ход: НЕТ", "Когда бьет фигуру: ДА", sep='\n')
  else:
    print("Обычный ход: НЕТ", "Когда бьет фигуру: НЕТ", sep='\n')
else:
  print("Обычный ход: НЕТ", "Когда бьет фигуру: НЕТ", sep='\n')
# Out:
# 8 7 8 5
# Обычный ход: ДА
# Когда бьет фигуру: НЕТ
